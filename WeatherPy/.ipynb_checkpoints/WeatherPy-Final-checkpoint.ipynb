# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import io
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city= citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
no_of_cities = len(cities)
len(cities)
no_of_cities
# Out:
# 630

# %%
city_dictionary ={
    "city": cities,
    "country": "",
    "latitude": "",
    "longitude": "",
    "humidity": "",
    "cloudiness": "",
    "windspeed":"",
    "temperature": ""
                 }    

new_cities_df = pd.DataFrame(city_dictionary)

new_cities_df.head()
# Out:
#             city country latitude longitude humidity cloudiness windspeed  \
# 0     lavrentiya
# 1     maningrida
# 2        rikitea
# 3      massakory
# 4  cockburn town
#
#   temperature
# 0
# 1
# 2
# 3
# 4

# %%
base_url = "https://api.openweathermap.org/data/2.5/weather?"

units="imperial"
 
call_url = f"{base_url}appid={weather_api_key}&units={units}&q="    
 
# Use iterrows to iterate through pandas dataframe
for index, row in new_cities_df.iterrows():
 
    # Get city from df
    city = row['city']
   
    
    # Make API Call
   
    print(f"Retrieving Results for OpenWeather City Weather {index}.")
    response = requests.get(call_url + city).json()
    time.sleep(.15)
    
    # Get Results
    results = response['cod']
    
    try:
        print(f"City found is " + city + " with ID: " , response['id'] ) 
        
        new_cities_df.loc[index, 'country'] = response['sys']['country']
        new_cities_df.loc[index, 'latitude'] = response['coord']['lat']
        new_cities_df.loc[index, 'longitude'] = response['coord']['lon']
        new_cities_df.loc[index, 'humidity'] = response['main']['humidity']
        new_cities_df.loc[index, 'cloudiness'] = response['clouds']['all']
        new_cities_df.loc[index, 'windspeed'] = response['wind']['speed']
        new_cities_df.loc[index, 'temperature'] = response['main']['temp']
        
        
    except (KeyError, IndexError):
        print("City weather not available")
        
    print("------------")
# Out:
# Retrieving Results for OpenWeather City Weather 0.
# City found is lavrentiya with ID:  4031637
# ------------
# Retrieving Results for OpenWeather City Weather 1.
# City found is maningrida with ID:  2067089
# ------------
# Retrieving Results for OpenWeather City Weather 2.
# City found is rikitea with ID:  4030556
# ------------
# Retrieving Results for OpenWeather City Weather 3.
# City found is massakory with ID:  2428228
# ------------
# Retrieving Results for OpenWeather City Weather 4.
# City found is cockburn town with ID:  3576994
# ------------
# Retrieving Results for OpenWeather City Weather 5.
# City found is albany with ID:  5106841
# ------------
# Retrieving Results for OpenWeather City Weather 6.
# City found is tyukalinsk with ID:  1488780
# ------------
# Retrieving Results for OpenWeather City Weather 7.
# City found is batemans bay with ID:  2176639
# ------------
# Retrieving Results for OpenWeather City Weather 8.
# City found is maceio with ID:  3395981
# ------------
# Retrieving Results for OpenWeather City Weather 9.
# City found is saint-philippe with ID:  935215
# ------------
# Retrieving Results for OpenWeather City Weather 10.
# City found is port hawkesbury with ID:  6111867
# ------------
# Retrieving Results for OpenWeather City Weather 11.
# City found is pisco with ID:  3932145
# ------------
# Retrieving Results for OpenWeather City Weather 12.
# City found is port shepstone with ID:  964406
# ------------
# Retrieving Results for OpenWeather City Weather 13.
# City found is jamestown with ID:  5122534
# ------------
# Retrieving Results for OpenWeather City Weather 14.
# City found is torbay with ID:  6167817
# ------------
# Retrieving Results for OpenWeather City Weather 15.
# City found is batouri with ID:  2234663
# ------------
# Retrieving Results for OpenWeather City Weather 16.
# City found is kudahuvadhoo with ID:  1337607
# ------------
# Retrieving Results for OpenWeather City Weather 17.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 18.
# City found is xinmin with ID:  2033675
# ------------
# Retrieving Results for OpenWeather City Weather 19.
# City found is punta arenas with ID:  3874787
# ------------
# Retrieving Results for OpenWeather City Weather 20.
# City found is mbeya with ID:  154380
# ------------
# Retrieving Results for OpenWeather City Weather 21.
# City found is ustye with ID:  477846
# ------------
# Retrieving Results for OpenWeather City Weather 22.
# City found is ushuaia with ID:  3833367
# ------------
# Retrieving Results for OpenWeather City Weather 23.
# City found is port hueneme with ID:  5384339
# ------------
# Retrieving Results for OpenWeather City Weather 24.
# City found is bubaque with ID:  2374583
# ------------
# Retrieving Results for OpenWeather City Weather 25.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 26.
# City found is qaqortoq with ID:  3420846
# ------------
# Retrieving Results for OpenWeather City Weather 27.
# City found is puerto ayora with ID:  3652764
# ------------
# Retrieving Results for OpenWeather City Weather 28.
# City found is chuy with ID:  3443061
# ------------
# Retrieving Results for OpenWeather City Weather 29.
# City found is hilo with ID:  5855927
# ------------
# Retrieving Results for OpenWeather City Weather 30.
# City found is antofagasta with ID:  3899539
# ------------
# Retrieving Results for OpenWeather City Weather 31.
# City found is alice springs with ID:  2077895
# ------------
# Retrieving Results for OpenWeather City Weather 32.
# City found is leningradskiy with ID:  2123814
# ------------
# Retrieving Results for OpenWeather City Weather 33.
# City found is ambon with ID:  1651531
# ------------
# Retrieving Results for OpenWeather City Weather 34.
# City found is kapaa with ID:  5848280
# ------------
# Retrieving Results for OpenWeather City Weather 35.
# City found is qaanaaq with ID:  3831208
# ------------
# Retrieving Results for OpenWeather City Weather 36.
# City found is palasa with ID:  1260771
# ------------
# Retrieving Results for OpenWeather City Weather 37.
# City found is mar del plata with ID:  3430863
# ------------
# Retrieving Results for OpenWeather City Weather 38.
# City found is mogadishu with ID:  53654
# ------------
# Retrieving Results for OpenWeather City Weather 39.
# City found is sao joao da barra with ID:  3448903
# ------------
# Retrieving Results for OpenWeather City Weather 40.
# City found is kisangani with ID:  212730
# ------------
# Retrieving Results for OpenWeather City Weather 41.
# City found is boguchany with ID:  1509844
# ------------
# Retrieving Results for OpenWeather City Weather 42.
# City found is port alfred with ID:  964432
# ------------
# Retrieving Results for OpenWeather City Weather 43.
# City found is sol-iletsk with ID:  491019
# ------------
# Retrieving Results for OpenWeather City Weather 44.
# City found is bethel with ID:  5282297
# ------------
# Retrieving Results for OpenWeather City Weather 45.
# City found is tambopata with ID:  3927942
# ------------
# Retrieving Results for OpenWeather City Weather 46.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 47.
# City found is mataura with ID:  6201424
# ------------
# Retrieving Results for OpenWeather City Weather 48.
# City found is yashkul with ID:  468747
# ------------
# Retrieving Results for OpenWeather City Weather 49.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 50.
# City found is dingle with ID:  1714733
# ------------
# Retrieving Results for OpenWeather City Weather 51.
# City found is shumikha with ID:  1491999
# ------------
# Retrieving Results for OpenWeather City Weather 52.
# City found is kirksville with ID:  5055787
# ------------
# Retrieving Results for OpenWeather City Weather 53.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 54.
# City found is butaritari with ID:  2110227
# ------------
# Retrieving Results for OpenWeather City Weather 55.
# City found is morgan city with ID:  4333811
# ------------
# Retrieving Results for OpenWeather City Weather 56.
# City found is atuona with ID:  4020109
# ------------
# Retrieving Results for OpenWeather City Weather 57.
# City found is lubao with ID:  1705441
# ------------
# Retrieving Results for OpenWeather City Weather 58.
# City found is victoria with ID:  1819729
# ------------
# Retrieving Results for OpenWeather City Weather 59.
# City found is cape town with ID:  3369157
# ------------
# Retrieving Results for OpenWeather City Weather 60.
# City found is geraldton with ID:  2070998
# ------------
# Retrieving Results for OpenWeather City Weather 61.
# City found is talavera with ID:  1684019
# ------------
# Retrieving Results for OpenWeather City Weather 62.
# City found is port hedland with ID:  2063042
# ------------
# Retrieving Results for OpenWeather City Weather 63.
# City found is thompson with ID:  6165406
# ------------
# Retrieving Results for OpenWeather City Weather 64.
# City found is busselton with ID:  2075265
# ------------
# Retrieving Results for OpenWeather City Weather 65.
# City found is arlit with ID:  2447513
# ------------
# Retrieving Results for OpenWeather City Weather 66.
# City found is saint-pierre with ID:  935214
# ------------
# Retrieving Results for OpenWeather City Weather 67.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 68.
# City found is pokhara with ID:  1282898
# ------------
# Retrieving Results for OpenWeather City Weather 69.
# City found is pimentel with ID:  3693584
# ------------
# Retrieving Results for OpenWeather City Weather 70.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 71.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 72.
# City found is waipawa with ID:  2206874
# ------------
# Retrieving Results for OpenWeather City Weather 73.
# City found is barrow with ID:  5880054
# ------------
# Retrieving Results for OpenWeather City Weather 74.
# City found is hithadhoo with ID:  1282256
# ------------
# Retrieving Results for OpenWeather City Weather 75.
# City found is kefamenanu with ID:  1640576
# ------------
# Retrieving Results for OpenWeather City Weather 76.
# City found is cururupu with ID:  3401148
# ------------
# Retrieving Results for OpenWeather City Weather 77.
# City found is porto novo with ID:  2392087
# ------------
# Retrieving Results for OpenWeather City Weather 78.
# City found is avarua with ID:  4035715
# ------------
# Retrieving Results for OpenWeather City Weather 79.
# City found is kharp with ID:  1503726
# ------------
# Retrieving Results for OpenWeather City Weather 80.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 81.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 82.
# City found is sitka with ID:  5557293
# ------------
# Retrieving Results for OpenWeather City Weather 83.
# City found is tsiroanomandidy with ID:  1054463
# ------------
# Retrieving Results for OpenWeather City Weather 84.
# City found is lompoc with ID:  5367788
# ------------
# Retrieving Results for OpenWeather City Weather 85.
# City found is yuzhno-kurilsk with ID:  2119447
# ------------
# Retrieving Results for OpenWeather City Weather 86.
# City found is saskylakh with ID:  2017155
# ------------
# Retrieving Results for OpenWeather City Weather 87.
# City found is sakakah with ID:  102527
# ------------
# Retrieving Results for OpenWeather City Weather 88.
# City found is vao with ID:  2137773
# ------------
# Retrieving Results for OpenWeather City Weather 89.
# City found is castro with ID:  3466704
# ------------
# Retrieving Results for OpenWeather City Weather 90.
# City found is ola with ID:  2122574
# ------------
# Retrieving Results for OpenWeather City Weather 91.
# City found is wattegama with ID:  1224061
# ------------
# Retrieving Results for OpenWeather City Weather 92.
# City found is dukat with ID:  2125906
# ------------
# Retrieving Results for OpenWeather City Weather 93.
# City found is khatanga with ID:  2022572
# ------------
# Retrieving Results for OpenWeather City Weather 94.
# City found is bredasdorp with ID:  1015776
# ------------
# Retrieving Results for OpenWeather City Weather 95.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 96.
# City found is cherskiy with ID:  2126199
# ------------
# Retrieving Results for OpenWeather City Weather 97.
# City found is meulaboh with ID:  1214488
# ------------
# Retrieving Results for OpenWeather City Weather 98.
# City found is port blair with ID:  1259385
# ------------
# Retrieving Results for OpenWeather City Weather 99.
# City found is bilma with ID:  2446796
# ------------
# Retrieving Results for OpenWeather City Weather 100.
# City found is santa cruz with ID:  3904906
# ------------
# Retrieving Results for OpenWeather City Weather 101.
# City found is tasiilaq with ID:  3424607
# ------------
# Retrieving Results for OpenWeather City Weather 102.
# City found is fairbanks with ID:  5861897
# ------------
# Retrieving Results for OpenWeather City Weather 103.
# City found is tashla with ID:  484232
# ------------
# Retrieving Results for OpenWeather City Weather 104.
# City found is caravelas with ID:  3466980
# ------------
# Retrieving Results for OpenWeather City Weather 105.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 106.
# City found is luderitz with ID:  3355672
# ------------
# Retrieving Results for OpenWeather City Weather 107.
# City found is dungarpur with ID:  1272201
# ------------
# Retrieving Results for OpenWeather City Weather 108.
# City found is aranos with ID:  3358666
# ------------
# Retrieving Results for OpenWeather City Weather 109.
# City found is talcahuano with ID:  3870282
# ------------
# Retrieving Results for OpenWeather City Weather 110.
# City found is tarragona with ID:  3108287
# ------------
# Retrieving Results for OpenWeather City Weather 111.
# City found is masindi with ID:  229362
# ------------
# Retrieving Results for OpenWeather City Weather 112.
# City found is hermanus with ID:  3366880
# ------------
# Retrieving Results for OpenWeather City Weather 113.
# City found is dikson with ID:  1507390
# ------------
# Retrieving Results for OpenWeather City Weather 114.
# City found is carutapera with ID:  3402648
# ------------
# Retrieving Results for OpenWeather City Weather 115.
# City found is dunedin with ID:  2191562
# ------------
# Retrieving Results for OpenWeather City Weather 116.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 117.
# City found is kodiak with ID:  5866583
# ------------
# Retrieving Results for OpenWeather City Weather 118.
# City found is ponta do sol with ID:  2264557
# ------------
# Retrieving Results for OpenWeather City Weather 119.
# City found is dzhebariki-khaya with ID:  2024626
# ------------
# Retrieving Results for OpenWeather City Weather 120.
# City found is bocana de paiwas with ID:  3620661
# ------------
# Retrieving Results for OpenWeather City Weather 121.
# City found is urumqi with ID:  1529102
# ------------
# Retrieving Results for OpenWeather City Weather 122.
# City found is genhe with ID:  2037252
# ------------
# Retrieving Results for OpenWeather City Weather 123.
# City found is tuatapere with ID:  2180815
# ------------
# Retrieving Results for OpenWeather City Weather 124.
# City found is yar-sale with ID:  1486321
# ------------
# Retrieving Results for OpenWeather City Weather 125.
# City found is sidi ali with ID:  2487130
# ------------
# Retrieving Results for OpenWeather City Weather 126.
# City found is namatanai with ID:  2090021
# ------------
# Retrieving Results for OpenWeather City Weather 127.
# City found is chokurdakh with ID:  2126123
# ------------
# Retrieving Results for OpenWeather City Weather 128.
# City found is homer with ID:  5864145
# ------------
# Retrieving Results for OpenWeather City Weather 129.
# City found is new norfolk with ID:  2155415
# ------------
# Retrieving Results for OpenWeather City Weather 130.
# City found is cabo san lucas with ID:  3985710
# ------------
# Retrieving Results for OpenWeather City Weather 131.
# City found is lorengau with ID:  2092164
# ------------
# Retrieving Results for OpenWeather City Weather 132.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 133.
# City found is namibe with ID:  3347019
# ------------
# Retrieving Results for OpenWeather City Weather 134.
# City found is isangel with ID:  2136825
# ------------
# Retrieving Results for OpenWeather City Weather 135.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 136.
# City found is vaini with ID:  4032243
# ------------
# Retrieving Results for OpenWeather City Weather 137.
# City found is ucluelet with ID:  6171633
# ------------
# Retrieving Results for OpenWeather City Weather 138.
# City found is sonoita with ID:  3982837
# ------------
# Retrieving Results for OpenWeather City Weather 139.
# City found is vestmannaeyjar with ID:  3412093
# ------------
# Retrieving Results for OpenWeather City Weather 140.
# City found is beringovskiy with ID:  2126710
# ------------
# Retrieving Results for OpenWeather City Weather 141.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 142.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 143.
# City found is iguape with ID:  3461465
# ------------
# Retrieving Results for OpenWeather City Weather 144.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 145.
# City found is skibbereen with ID:  2961459
# ------------
# Retrieving Results for OpenWeather City Weather 146.
# City found is sinnamary with ID:  3380290
# ------------
# Retrieving Results for OpenWeather City Weather 147.
# City found is pangnirtung with ID:  6096551
# ------------
# Retrieving Results for OpenWeather City Weather 148.
# City found is karratha with ID:  6620339
# ------------
# Retrieving Results for OpenWeather City Weather 149.
# City found is hobart with ID:  2163355
# ------------
# Retrieving Results for OpenWeather City Weather 150.
# City found is harper with ID:  2276492
# ------------
# Retrieving Results for OpenWeather City Weather 151.
# City found is awbari with ID:  2219235
# ------------
# Retrieving Results for OpenWeather City Weather 152.
# City found is nouadhibou with ID:  2377457
# ------------
# Retrieving Results for OpenWeather City Weather 153.
# City found is ilulissat with ID:  3423146
# ------------
# Retrieving Results for OpenWeather City Weather 154.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 155.
# City found is dali with ID:  1814093
# ------------
# Retrieving Results for OpenWeather City Weather 156.
# City found is klaksvik with ID:  2618795
# ------------
# Retrieving Results for OpenWeather City Weather 157.
# City found is olafsvik with ID:  3414079
# ------------
# Retrieving Results for OpenWeather City Weather 158.
# City found is alofi with ID:  4036284
# ------------
# Retrieving Results for OpenWeather City Weather 159.
# City found is prince rupert with ID:  6113406
# ------------
# Retrieving Results for OpenWeather City Weather 160.
# City found is bengkulu with ID:  1649150
# ------------
# Retrieving Results for OpenWeather City Weather 161.
# City found is phan thiet with ID:  1571058
# ------------
# Retrieving Results for OpenWeather City Weather 162.
# City found is kahului with ID:  5847411
# ------------
# Retrieving Results for OpenWeather City Weather 163.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 164.
# City found is mount gambier with ID:  2156643
# ------------
# Retrieving Results for OpenWeather City Weather 165.
# City found is esperance with ID:  2071860
# ------------
# Retrieving Results for OpenWeather City Weather 166.
# City found is bulaevo with ID:  1525014
# ------------
# Retrieving Results for OpenWeather City Weather 167.
# City found is oussouye with ID:  2246901
# ------------
# Retrieving Results for OpenWeather City Weather 168.
# City found is moussoro with ID:  2427336
# ------------
# Retrieving Results for OpenWeather City Weather 169.
# City found is nikolskoye with ID:  546105
# ------------
# Retrieving Results for OpenWeather City Weather 170.
# City found is cayenne with ID:  3382160
# ------------
# Retrieving Results for OpenWeather City Weather 171.
# City found is guilin with ID:  1809498
# ------------
# Retrieving Results for OpenWeather City Weather 172.
# City found is neiafu with ID:  4032420
# ------------
# Retrieving Results for OpenWeather City Weather 173.
# City found is tank with ID:  1163905
# ------------
# Retrieving Results for OpenWeather City Weather 174.
# City found is barcelos with ID:  2742416
# ------------
# Retrieving Results for OpenWeather City Weather 175.
# City found is nanhai with ID:  7696234
# ------------
# Retrieving Results for OpenWeather City Weather 176.
# City found is kon tum with ID:  1578500
# ------------
# Retrieving Results for OpenWeather City Weather 177.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 178.
# City found is sao filipe with ID:  3374210
# ------------
# Retrieving Results for OpenWeather City Weather 179.
# City found is izhma with ID:  554830
# ------------
# Retrieving Results for OpenWeather City Weather 180.
# City found is huilong with ID:  1806840
# ------------
# Retrieving Results for OpenWeather City Weather 181.
# City found is gondanglegi with ID:  1640660
# ------------
# Retrieving Results for OpenWeather City Weather 182.
# City found is port-cartier with ID:  6111696
# ------------
# Retrieving Results for OpenWeather City Weather 183.
# City found is komsomolskiy with ID:  1513491
# ------------
# Retrieving Results for OpenWeather City Weather 184.
# City found is bjornevatn with ID:  780643
# ------------
# Retrieving Results for OpenWeather City Weather 185.
# City found is mount darwin with ID:  885800
# ------------
# Retrieving Results for OpenWeather City Weather 186.
# City found is padang with ID:  1633419
# ------------
# Retrieving Results for OpenWeather City Weather 187.
# City found is leshukonskoye with ID:  535839
# ------------
# Retrieving Results for OpenWeather City Weather 188.
# City found is severodvinsk with ID:  496285
# ------------
# Retrieving Results for OpenWeather City Weather 189.
# City found is mahebourg with ID:  934322
# ------------
# Retrieving Results for OpenWeather City Weather 190.
# City found is arman with ID:  2127060
# ------------
# Retrieving Results for OpenWeather City Weather 191.
# City found is salekhard with ID:  1493197
# ------------
# Retrieving Results for OpenWeather City Weather 192.
# City found is chara with ID:  2025630
# ------------
# Retrieving Results for OpenWeather City Weather 193.
# City found is verkhnyaya inta with ID:  1487332
# ------------
# Retrieving Results for OpenWeather City Weather 194.
# City found is tiznit with ID:  2527087
# ------------
# Retrieving Results for OpenWeather City Weather 195.
# City found is sept-iles with ID:  6144312
# ------------
# Retrieving Results for OpenWeather City Weather 196.
# City found is miri with ID:  1738050
# ------------
# Retrieving Results for OpenWeather City Weather 197.
# City found is oyem with ID:  2396646
# ------------
# Retrieving Results for OpenWeather City Weather 198.
# City found is sibut with ID:  2383119
# ------------
# Retrieving Results for OpenWeather City Weather 199.
# City found is hasaki with ID:  2112802
# ------------
# Retrieving Results for OpenWeather City Weather 200.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 201.
# City found is erenhot with ID:  2037485
# ------------
# Retrieving Results for OpenWeather City Weather 202.
# City found is shambu with ID:  328709
# ------------
# Retrieving Results for OpenWeather City Weather 203.
# City found is belmonte with ID:  3470137
# ------------
# Retrieving Results for OpenWeather City Weather 204.
# City found is westport with ID:  4845585
# ------------
# Retrieving Results for OpenWeather City Weather 205.
# City found is kavieng with ID:  2094342
# ------------
# Retrieving Results for OpenWeather City Weather 206.
# City found is turayf with ID:  101312
# ------------
# Retrieving Results for OpenWeather City Weather 207.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 208.
# City found is acajutla with ID:  3587498
# ------------
# Retrieving Results for OpenWeather City Weather 209.
# City found is ishigaki with ID:  1861416
# ------------
# Retrieving Results for OpenWeather City Weather 210.
# City found is altay with ID:  1529651
# ------------
# Retrieving Results for OpenWeather City Weather 211.
# City found is imbituba with ID:  3461370
# ------------
# Retrieving Results for OpenWeather City Weather 212.
# City found is kununurra with ID:  2068110
# ------------
# Retrieving Results for OpenWeather City Weather 213.
# City found is salalah with ID:  286621
# ------------
# Retrieving Results for OpenWeather City Weather 214.
# City found is ostrovnoy with ID:  556268
# ------------
# Retrieving Results for OpenWeather City Weather 215.
# City found is yellowknife with ID:  6185377
# ------------
# Retrieving Results for OpenWeather City Weather 216.
# City found is marsh harbour with ID:  3571913
# ------------
# Retrieving Results for OpenWeather City Weather 217.
# City found is sorland with ID:  3137469
# ------------
# Retrieving Results for OpenWeather City Weather 218.
# City found is male with ID:  1282027
# ------------
# Retrieving Results for OpenWeather City Weather 219.
# City found is vista hermosa with ID:  3514633
# ------------
# Retrieving Results for OpenWeather City Weather 220.
# City found is tuktoyaktuk with ID:  6170031
# ------------
# Retrieving Results for OpenWeather City Weather 221.
# City found is ialibu with ID:  2095925
# ------------
# Retrieving Results for OpenWeather City Weather 222.
# City found is beberibe with ID:  3405924
# ------------
# Retrieving Results for OpenWeather City Weather 223.
# City found is bayburt with ID:  750938
# ------------
# Retrieving Results for OpenWeather City Weather 224.
# City found is ossora with ID:  2122389
# ------------
# Retrieving Results for OpenWeather City Weather 225.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 226.
# City found is coquimbo with ID:  3893629
# ------------
# Retrieving Results for OpenWeather City Weather 227.
# City found is dicabisagan with ID:  1715015
# ------------
# Retrieving Results for OpenWeather City Weather 228.
# City found is agropoli with ID:  6541176
# ------------
# Retrieving Results for OpenWeather City Weather 229.
# City found is airai with ID:  1651810
# ------------
# Retrieving Results for OpenWeather City Weather 230.
# City found is souillac with ID:  933995
# ------------
# Retrieving Results for OpenWeather City Weather 231.
# City found is marawi with ID:  1701054
# ------------
# Retrieving Results for OpenWeather City Weather 232.
# City found is mareeba with ID:  2158767
# ------------
# Retrieving Results for OpenWeather City Weather 233.
# City found is cody with ID:  5821593
# ------------
# Retrieving Results for OpenWeather City Weather 234.
# City found is diffa with ID:  2445704
# ------------
# Retrieving Results for OpenWeather City Weather 235.
# City found is ugoofaaru with ID:  1337619
# ------------
# Retrieving Results for OpenWeather City Weather 236.
# City found is shushtar with ID:  114584
# ------------
# Retrieving Results for OpenWeather City Weather 237.
# City found is sur with ID:  286245
# ------------
# Retrieving Results for OpenWeather City Weather 238.
# City found is lebu with ID:  3883457
# ------------
# Retrieving Results for OpenWeather City Weather 239.
# City found is garden city with ID:  4993659
# ------------
# Retrieving Results for OpenWeather City Weather 240.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 241.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 242.
# City found is georgetown with ID:  1735106
# ------------
# Retrieving Results for OpenWeather City Weather 243.
# City found is upernavik with ID:  3418910
# ------------
# Retrieving Results for OpenWeather City Weather 244.
# City found is menongue with ID:  3347353
# ------------
# Retrieving Results for OpenWeather City Weather 245.
# City found is acarau with ID:  3408368
# ------------
# Retrieving Results for OpenWeather City Weather 246.
# City found is nuevitas with ID:  3545841
# ------------
# Retrieving Results for OpenWeather City Weather 247.
# City found is kampong cham with ID:  1831173
# ------------
# Retrieving Results for OpenWeather City Weather 248.
# City found is provideniya with ID:  4031574
# ------------
# Retrieving Results for OpenWeather City Weather 249.
# City found is bluff with ID:  2206939
# ------------
# Retrieving Results for OpenWeather City Weather 250.
# City found is russell with ID:  4047434
# ------------
# Retrieving Results for OpenWeather City Weather 251.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 252.
# City found is omboue with ID:  2396853
# ------------
# Retrieving Results for OpenWeather City Weather 253.
# City found is upata with ID:  3625710
# ------------
# Retrieving Results for OpenWeather City Weather 254.
# City found is college with ID:  5859699
# ------------
# Retrieving Results for OpenWeather City Weather 255.
# City found is wanning with ID:  1791779
# ------------
# Retrieving Results for OpenWeather City Weather 256.
# City found is nioro with ID:  2412408
# ------------
# Retrieving Results for OpenWeather City Weather 257.
# City found is ramhormoz with ID:  118826
# ------------
# Retrieving Results for OpenWeather City Weather 258.
# City found is moindou with ID:  2140466
# ------------
# Retrieving Results for OpenWeather City Weather 259.
# City found is raudeberg with ID:  3146487
# ------------
# Retrieving Results for OpenWeather City Weather 260.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 261.
# City found is byron bay with ID:  2172880
# ------------
# Retrieving Results for OpenWeather City Weather 262.
# City found is akureyri with ID:  2633274
# ------------
# Retrieving Results for OpenWeather City Weather 263.
# City found is abasolo with ID:  4019869
# ------------
# Retrieving Results for OpenWeather City Weather 264.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 265.
# City found is hofn with ID:  2630299
# ------------
# Retrieving Results for OpenWeather City Weather 266.
# City found is longyearbyen with ID:  2729907
# ------------
# Retrieving Results for OpenWeather City Weather 267.
# City found is pevek with ID:  2122090
# ------------
# Retrieving Results for OpenWeather City Weather 268.
# City found is camopi with ID:  3382226
# ------------
# Retrieving Results for OpenWeather City Weather 269.
# City found is mayya with ID:  2020121
# ------------
# Retrieving Results for OpenWeather City Weather 270.
# City found is san policarpo with ID:  1688696
# ------------
# Retrieving Results for OpenWeather City Weather 271.
# City found is mali with ID:  2417886
# ------------
# Retrieving Results for OpenWeather City Weather 272.
# City found is severo-kurilsk with ID:  2121385
# ------------
# Retrieving Results for OpenWeather City Weather 273.
# City found is zdvinsk with ID:  1485312
# ------------
# Retrieving Results for OpenWeather City Weather 274.
# City found is rocha with ID:  3440777
# ------------
# Retrieving Results for OpenWeather City Weather 275.
# City found is clyde river with ID:  5924351
# ------------
# Retrieving Results for OpenWeather City Weather 276.
# City found is korla with ID:  1529376
# ------------
# Retrieving Results for OpenWeather City Weather 277.
# City found is chapais with ID:  5919850
# ------------
# Retrieving Results for OpenWeather City Weather 278.
# City found is cidreira with ID:  3466165
# ------------
# Retrieving Results for OpenWeather City Weather 279.
# City found is carnarvon with ID:  2074865
# ------------
# Retrieving Results for OpenWeather City Weather 280.
# City found is ust-kut with ID:  2013923
# ------------
# Retrieving Results for OpenWeather City Weather 281.
# City found is grootfontein with ID:  3357114
# ------------
# Retrieving Results for OpenWeather City Weather 282.
# City found is mmathubudukwane with ID:  933347
# ------------
# Retrieving Results for OpenWeather City Weather 283.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 284.
# City found is romny with ID:  695464
# ------------
# Retrieving Results for OpenWeather City Weather 285.
# City found is flinders with ID:  6255012
# ------------
# Retrieving Results for OpenWeather City Weather 286.
# City found is hluti with ID:  935076
# ------------
# Retrieving Results for OpenWeather City Weather 287.
# City found is bandarbeyla with ID:  64814
# ------------
# Retrieving Results for OpenWeather City Weather 288.
# City found is tura with ID:  1254046
# ------------
# Retrieving Results for OpenWeather City Weather 289.
# City found is lodja with ID:  211647
# ------------
# Retrieving Results for OpenWeather City Weather 290.
# City found is goderich with ID:  5962442
# ------------
# Retrieving Results for OpenWeather City Weather 291.
# City found is ladario with ID:  3459352
# ------------
# Retrieving Results for OpenWeather City Weather 292.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 293.
# City found is qeshm with ID:  119374
# ------------
# Retrieving Results for OpenWeather City Weather 294.
# City found is anadyr with ID:  2127202
# ------------
# Retrieving Results for OpenWeather City Weather 295.
# City found is xam nua with ID:  1652203
# ------------
# Retrieving Results for OpenWeather City Weather 296.
# City found is san pedro with ID:  1688781
# ------------
# Retrieving Results for OpenWeather City Weather 297.
# City found is koumac with ID:  2140558
# ------------
# Retrieving Results for OpenWeather City Weather 298.
# City found is gat with ID:  293842
# ------------
# Retrieving Results for OpenWeather City Weather 299.
# City found is boden with ID:  606531
# ------------
# Retrieving Results for OpenWeather City Weather 300.
# City found is show low with ID:  5314245
# ------------
# Retrieving Results for OpenWeather City Weather 301.
# City found is taoudenni with ID:  2450173
# ------------
# Retrieving Results for OpenWeather City Weather 302.
# City found is morton with ID:  5690583
# ------------
# Retrieving Results for OpenWeather City Weather 303.
# City found is coihaique with ID:  3894426
# ------------
# Retrieving Results for OpenWeather City Weather 304.
# City found is vardo with ID:  777019
# ------------
# Retrieving Results for OpenWeather City Weather 305.
# City found is tiksi with ID:  2015306
# ------------
# Retrieving Results for OpenWeather City Weather 306.
# City found is port augusta with ID:  2063056
# ------------
# Retrieving Results for OpenWeather City Weather 307.
# City found is aitape with ID:  2101169
# ------------
# Retrieving Results for OpenWeather City Weather 308.
# City found is nueva guinea with ID:  3617459
# ------------
# Retrieving Results for OpenWeather City Weather 309.
# City found is vanimo with ID:  2084442
# ------------
# Retrieving Results for OpenWeather City Weather 310.
# City found is saint-francois with ID:  2980080
# ------------
# Retrieving Results for OpenWeather City Weather 311.
# City found is mehamn with ID:  778707
# ------------
# Retrieving Results for OpenWeather City Weather 312.
# City found is machali with ID:  3881102
# ------------
# Retrieving Results for OpenWeather City Weather 313.
# City found is hammerfest with ID:  779683
# ------------
# Retrieving Results for OpenWeather City Weather 314.
# City found is vila franca do campo with ID:  3372472
# ------------
# Retrieving Results for OpenWeather City Weather 315.
# City found is grand gaube with ID:  934479
# ------------
# Retrieving Results for OpenWeather City Weather 316.
# City found is prieska with ID:  964090
# ------------
# Retrieving Results for OpenWeather City Weather 317.
# City found is sabang with ID:  1214026
# ------------
# Retrieving Results for OpenWeather City Weather 318.
# City found is hobyo with ID:  57000
# ------------
# Retrieving Results for OpenWeather City Weather 319.
# City found is kaitangata with ID:  2208248
# ------------
# Retrieving Results for OpenWeather City Weather 320.
# City found is madinat sittah uktubar with ID:  353219
# ------------
# Retrieving Results for OpenWeather City Weather 321.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 322.
# City found is moissala with ID:  2427697
# ------------
# Retrieving Results for OpenWeather City Weather 323.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 324.
# City found is jizan with ID:  105298
# ------------
# Retrieving Results for OpenWeather City Weather 325.
# City found is berlevag with ID:  780687
# ------------
# Retrieving Results for OpenWeather City Weather 326.
# City found is fangshan with ID:  1811542
# ------------
# Retrieving Results for OpenWeather City Weather 327.
# City found is mahon with ID:  2514301
# ------------
# Retrieving Results for OpenWeather City Weather 328.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 329.
# City found is naze with ID:  1855540
# ------------
# Retrieving Results for OpenWeather City Weather 330.
# City found is mulchen with ID:  3879200
# ------------
# Retrieving Results for OpenWeather City Weather 331.
# City found is faanui with ID:  4034551
# ------------
# Retrieving Results for OpenWeather City Weather 332.
# City found is fort-shevchenko with ID:  609906
# ------------
# Retrieving Results for OpenWeather City Weather 333.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 334.
# City found is khanpur with ID:  1174167
# ------------
# Retrieving Results for OpenWeather City Weather 335.
# City found is husavik with ID:  2629833
# ------------
# Retrieving Results for OpenWeather City Weather 336.
# City found is ribeira grande with ID:  3372707
# ------------
# Retrieving Results for OpenWeather City Weather 337.
# City found is bambous virieux with ID:  1106677
# ------------
# Retrieving Results for OpenWeather City Weather 338.
# City found is atambua with ID:  1651103
# ------------
# Retrieving Results for OpenWeather City Weather 339.
# City found is mayenne with ID:  2994933
# ------------
# Retrieving Results for OpenWeather City Weather 340.
# City found is marquette with ID:  5000950
# ------------
# Retrieving Results for OpenWeather City Weather 341.
# City found is saint george with ID:  5546220
# ------------
# Retrieving Results for OpenWeather City Weather 342.
# City found is nanortalik with ID:  3421765
# ------------
# Retrieving Results for OpenWeather City Weather 343.
# City found is broken hill with ID:  2173911
# ------------
# Retrieving Results for OpenWeather City Weather 344.
# City found is norman wells with ID:  6089245
# ------------
# Retrieving Results for OpenWeather City Weather 345.
# City found is kommunar with ID:  545788
# ------------
# Retrieving Results for OpenWeather City Weather 346.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 347.
# City found is sawakin with ID:  367544
# ------------
# Retrieving Results for OpenWeather City Weather 348.
# City found is taltal with ID:  3870243
# ------------
# Retrieving Results for OpenWeather City Weather 349.
# City found is mantenopolis with ID:  3457928
# ------------
# Retrieving Results for OpenWeather City Weather 350.
# City found is jumla with ID:  1283285
# ------------
# Retrieving Results for OpenWeather City Weather 351.
# City found is ancud with ID:  3899695
# ------------
# Retrieving Results for OpenWeather City Weather 352.
# City found is rosario with ID:  3838583
# ------------
# Retrieving Results for OpenWeather City Weather 353.
# City found is chake chake with ID:  160677
# ------------
# Retrieving Results for OpenWeather City Weather 354.
# City found is mabaruma with ID:  3377301
# ------------
# Retrieving Results for OpenWeather City Weather 355.
# City found is kiunga with ID:  2093846
# ------------
# Retrieving Results for OpenWeather City Weather 356.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 357.
# City found is limon with ID:  3622247
# ------------
# Retrieving Results for OpenWeather City Weather 358.
# City found is setermoen with ID:  3139765
# ------------
# Retrieving Results for OpenWeather City Weather 359.
# City found is umm kaddadah with ID:  364933
# ------------
# Retrieving Results for OpenWeather City Weather 360.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 361.
# City found is tautira with ID:  4033557
# ------------
# Retrieving Results for OpenWeather City Weather 362.
# City found is mount isa with ID:  2065594
# ------------
# Retrieving Results for OpenWeather City Weather 363.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 364.
# City found is luxor with ID:  360502
# ------------
# Retrieving Results for OpenWeather City Weather 365.
# City found is port elizabeth with ID:  964420
# ------------
# Retrieving Results for OpenWeather City Weather 366.
# City found is bayir with ID:  304183
# ------------
# Retrieving Results for OpenWeather City Weather 367.
# City found is diapaga with ID:  2361373
# ------------
# Retrieving Results for OpenWeather City Weather 368.
# City found is tezu with ID:  1254709
# ------------
# Retrieving Results for OpenWeather City Weather 369.
# City found is codrington with ID:  2171099
# ------------
# Retrieving Results for OpenWeather City Weather 370.
# City found is kachug with ID:  2023333
# ------------
# Retrieving Results for OpenWeather City Weather 371.
# City found is comodoro rivadavia with ID:  3860443
# ------------
# Retrieving Results for OpenWeather City Weather 372.
# City found is mandalgovi with ID:  2030065
# ------------
# Retrieving Results for OpenWeather City Weather 373.
# City found is rawson with ID:  3839307
# ------------
# Retrieving Results for OpenWeather City Weather 374.
# City found is praia da vitoria with ID:  3372760
# ------------
# Retrieving Results for OpenWeather City Weather 375.
# City found is flin flon with ID:  5954718
# ------------
# Retrieving Results for OpenWeather City Weather 376.
# City found is arraial do cabo with ID:  3471451
# ------------
# Retrieving Results for OpenWeather City Weather 377.
# City found is teya with ID:  1489656
# ------------
# Retrieving Results for OpenWeather City Weather 378.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 379.
# City found is markova with ID:  701802
# ------------
# Retrieving Results for OpenWeather City Weather 380.
# City found is jaslo with ID:  770293
# ------------
# Retrieving Results for OpenWeather City Weather 381.
# City found is lagoa with ID:  3372964
# ------------
# Retrieving Results for OpenWeather City Weather 382.
# City found is ipira with ID:  3461124
# ------------
# Retrieving Results for OpenWeather City Weather 383.
# City found is saldanha with ID:  3361934
# ------------
# Retrieving Results for OpenWeather City Weather 384.
# City found is mathathane with ID:  933383
# ------------
# Retrieving Results for OpenWeather City Weather 385.
# City found is rio grande with ID:  3451138
# ------------
# Retrieving Results for OpenWeather City Weather 386.
# City found is inirida with ID:  3671450
# ------------
# Retrieving Results for OpenWeather City Weather 387.
# City found is lewistown with ID:  5197850
# ------------
# Retrieving Results for OpenWeather City Weather 388.
# City found is gornyy with ID:  1506254
# ------------
# Retrieving Results for OpenWeather City Weather 389.
# City found is roald with ID:  3141667
# ------------
# Retrieving Results for OpenWeather City Weather 390.
# City found is kloulklubed with ID:  7671223
# ------------
# Retrieving Results for OpenWeather City Weather 391.
# City found is sitges with ID:  3108877
# ------------
# Retrieving Results for OpenWeather City Weather 392.
# City found is ixtapa with ID:  4004293
# ------------
# Retrieving Results for OpenWeather City Weather 393.
# City found is anito with ID:  1730622
# ------------
# Retrieving Results for OpenWeather City Weather 394.
# City found is ballina with ID:  2177069
# ------------
# Retrieving Results for OpenWeather City Weather 395.
# City found is kruisfontein with ID:  986717
# ------------
# Retrieving Results for OpenWeather City Weather 396.
# City found is mrakovo with ID:  524681
# ------------
# Retrieving Results for OpenWeather City Weather 397.
# City found is rio gallegos with ID:  3838859
# ------------
# Retrieving Results for OpenWeather City Weather 398.
# City found is helong with ID:  2036933
# ------------
# Retrieving Results for OpenWeather City Weather 399.
# City found is varadero with ID:  3534632
# ------------
# Retrieving Results for OpenWeather City Weather 400.
# City found is cap malheureux with ID:  934649
# ------------
# Retrieving Results for OpenWeather City Weather 401.
# City found is bud with ID:  4255151
# ------------
# Retrieving Results for OpenWeather City Weather 402.
# City found is kambja with ID:  588335
# ------------
# Retrieving Results for OpenWeather City Weather 403.
# City found is sabha with ID:  2212775
# ------------
# Retrieving Results for OpenWeather City Weather 404.
# City found is pontes e lacerda with ID:  3453060
# ------------
# Retrieving Results for OpenWeather City Weather 405.
# City found is tabuk with ID:  1684803
# ------------
# Retrieving Results for OpenWeather City Weather 406.
# City found is binzhou with ID:  1816336
# ------------
# Retrieving Results for OpenWeather City Weather 407.
# City found is pontianak with ID:  1630789
# ------------
# Retrieving Results for OpenWeather City Weather 408.
# City found is bairnsdale with ID:  2177233
# ------------
# Retrieving Results for OpenWeather City Weather 409.
# City found is sungaipenuh with ID:  1625929
# ------------
# Retrieving Results for OpenWeather City Weather 410.
# City found is pitimbu with ID:  3391889
# ------------
# Retrieving Results for OpenWeather City Weather 411.
# City found is mumford with ID:  2297810
# ------------
# Retrieving Results for OpenWeather City Weather 412.
# City found is moron with ID:  3430545
# ------------
# Retrieving Results for OpenWeather City Weather 413.
# City found is daru with ID:  2098329
# ------------
# Retrieving Results for OpenWeather City Weather 414.
# City found is chimbote with ID:  3698304
# ------------
# Retrieving Results for OpenWeather City Weather 415.
# City found is parfenyevo with ID:  512576
# ------------
# Retrieving Results for OpenWeather City Weather 416.
# City found is port hardy with ID:  6111862
# ------------
# Retrieving Results for OpenWeather City Weather 417.
# City found is semey with ID:  1519422
# ------------
# Retrieving Results for OpenWeather City Weather 418.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 419.
# City found is ketchikan with ID:  5554428
# ------------
# Retrieving Results for OpenWeather City Weather 420.
# City found is nha trang with ID:  1572151
# ------------
# Retrieving Results for OpenWeather City Weather 421.
# City found is havre-saint-pierre with ID:  5972291
# ------------
# Retrieving Results for OpenWeather City Weather 422.
# City found is saint pete beach with ID:  4171522
# ------------
# Retrieving Results for OpenWeather City Weather 423.
# City found is lincoln with ID:  5072006
# ------------
# Retrieving Results for OpenWeather City Weather 424.
# City found is lovozero with ID:  533933
# ------------
# Retrieving Results for OpenWeather City Weather 425.
# City found is golden with ID:  5423294
# ------------
# Retrieving Results for OpenWeather City Weather 426.
# City found is orlik with ID:  1496073
# ------------
# Retrieving Results for OpenWeather City Weather 427.
# City found is murwillumbah with ID:  2156049
# ------------
# Retrieving Results for OpenWeather City Weather 428.
# City found is svetlaya with ID:  2015852
# ------------
# Retrieving Results for OpenWeather City Weather 429.
# City found is pavlodar with ID:  1520240
# ------------
# Retrieving Results for OpenWeather City Weather 430.
# City found is balabac with ID:  1728675
# ------------
# Retrieving Results for OpenWeather City Weather 431.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 432.
# City found is puerto escondido with ID:  3520994
# ------------
# Retrieving Results for OpenWeather City Weather 433.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 434.
# City found is wahiawa with ID:  5853992
# ------------
# Retrieving Results for OpenWeather City Weather 435.
# City found is kokopo with ID:  2093685
# ------------
# Retrieving Results for OpenWeather City Weather 436.
# City found is porto velho with ID:  3662762
# ------------
# Retrieving Results for OpenWeather City Weather 437.
# City found is sistranda with ID:  3139597
# ------------
# Retrieving Results for OpenWeather City Weather 438.
# City found is kokoda with ID:  2093691
# ------------
# Retrieving Results for OpenWeather City Weather 439.
# City found is lafia with ID:  2332515
# ------------
# Retrieving Results for OpenWeather City Weather 440.
# City found is blackwater with ID:  2175403
# ------------
# Retrieving Results for OpenWeather City Weather 441.
# City found is utiel with ID:  2510075
# ------------
# Retrieving Results for OpenWeather City Weather 442.
# City found is fasa with ID:  134721
# ------------
# Retrieving Results for OpenWeather City Weather 443.
# City found is yablonovo with ID:  578283
# ------------
# Retrieving Results for OpenWeather City Weather 444.
# City found is ewa beach with ID:  5855051
# ------------
# Retrieving Results for OpenWeather City Weather 445.
# City found is chistogorskiy with ID:  1507801
# ------------
# Retrieving Results for OpenWeather City Weather 446.
# City found is katsuura with ID:  2112309
# ------------
# Retrieving Results for OpenWeather City Weather 447.
# City found is kupino with ID:  1501365
# ------------
# Retrieving Results for OpenWeather City Weather 448.
# City found is birao with ID:  240210
# ------------
# Retrieving Results for OpenWeather City Weather 449.
# City found is ilhabela with ID:  3461425
# ------------
# Retrieving Results for OpenWeather City Weather 450.
# City found is chicama with ID:  3698359
# ------------
# Retrieving Results for OpenWeather City Weather 451.
# City found is yumen with ID:  1528998
# ------------
# Retrieving Results for OpenWeather City Weather 452.
# City found is sioux lookout with ID:  6148373
# ------------
# Retrieving Results for OpenWeather City Weather 453.
# City found is sibolga with ID:  1213855
# ------------
# Retrieving Results for OpenWeather City Weather 454.
# City found is oriximina with ID:  3393471
# ...
# Retrieving Results for OpenWeather City Weather 478.
# City found is guerrero negro with ID:  4021858
# ------------
# Retrieving Results for OpenWeather City Weather 479.
# City found is roebourne with ID:  2062276
# ------------
# Retrieving Results for OpenWeather City Weather 480.
# City found is parkes with ID:  2153778
# ------------
# Retrieving Results for OpenWeather City Weather 481.
# City found is muros with ID:  3115824
# ------------
# Retrieving Results for OpenWeather City Weather 482.
# City found is asau with ID:  686090
# ------------
# Retrieving Results for OpenWeather City Weather 483.
# City found is tazovskiy with ID:  1489853
# ------------
# Retrieving Results for OpenWeather City Weather 484.
# City found is ginda with ID:  1253628
# ------------
# Retrieving Results for OpenWeather City Weather 485.
# City found is faya with ID:  110690
# ------------
# Retrieving Results for OpenWeather City Weather 486.
# City found is glace bay with ID:  5961564
# ------------
# Retrieving Results for OpenWeather City Weather 487.
# City found is greytown with ID:  1000006
# ------------
# Retrieving Results for OpenWeather City Weather 488.
# City found is pandan with ID:  1695546
# ------------
# Retrieving Results for OpenWeather City Weather 489.
# City found is hualmay with ID:  3939761
# ------------
# Retrieving Results for OpenWeather City Weather 490.
# City found is cairns with ID:  2172797
# ------------
# Retrieving Results for OpenWeather City Weather 491.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 492.
# City found is the valley with ID:  3573374
# ------------
# Retrieving Results for OpenWeather City Weather 493.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 494.
# City found is mandalay with ID:  1311874
# ------------
# Retrieving Results for OpenWeather City Weather 495.
# City found is haimen with ID:  1809062
# ------------
# Retrieving Results for OpenWeather City Weather 496.
# City found is keti bandar with ID:  1174451
# ------------
# Retrieving Results for OpenWeather City Weather 497.
# City found is nador with ID:  2541479
# ------------
# Retrieving Results for OpenWeather City Weather 498.
# City found is fethiye with ID:  314967
# ------------
# Retrieving Results for OpenWeather City Weather 499.
# City found is fare with ID:  4034496
# ------------
# Retrieving Results for OpenWeather City Weather 500.
# City found is zhezkazgan with ID:  1516589
# ------------
# Retrieving Results for OpenWeather City Weather 501.
# City found is vostok with ID:  2013279
# ------------
# Retrieving Results for OpenWeather City Weather 502.
# City found is kewanee with ID:  4898433
# ------------
# Retrieving Results for OpenWeather City Weather 503.
# City found is pictou with ID:  6104221
# ------------
# Retrieving Results for OpenWeather City Weather 504.
# City found is chupa with ID:  567589
# ------------
# Retrieving Results for OpenWeather City Weather 505.
# City found is mayo with ID:  4362001
# ------------
# Retrieving Results for OpenWeather City Weather 506.
# City found is manyana with ID:  933416
# ------------
# Retrieving Results for OpenWeather City Weather 507.
# City found is sidney with ID:  2147714
# ------------
# Retrieving Results for OpenWeather City Weather 508.
# City found is san luis with ID:  3837056
# ------------
# Retrieving Results for OpenWeather City Weather 509.
# City found is urucara with ID:  3385670
# ------------
# Retrieving Results for OpenWeather City Weather 510.
# City found is port lincoln with ID:  2063036
# ------------
# Retrieving Results for OpenWeather City Weather 511.
# City found is bouake with ID:  2290956
# ------------
# Retrieving Results for OpenWeather City Weather 512.
# City found is saiha with ID:  1257771
# ------------
# Retrieving Results for OpenWeather City Weather 513.
# City found is portland with ID:  5746545
# ------------
# Retrieving Results for OpenWeather City Weather 514.
# City found is sattenapalle with ID:  1257001
# ------------
# Retrieving Results for OpenWeather City Weather 515.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 516.
# City found is dubti with ID:  338554
# ------------
# Retrieving Results for OpenWeather City Weather 517.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 518.
# City found is hervey bay with ID:  2146219
# ------------
# Retrieving Results for OpenWeather City Weather 519.
# City found is kalmunai with ID:  1242110
# ------------
# Retrieving Results for OpenWeather City Weather 520.
# City found is thaba nchu with ID:  949703
# ------------
# Retrieving Results for OpenWeather City Weather 521.
# City found is lucapa with ID:  145724
# ------------
# Retrieving Results for OpenWeather City Weather 522.
# City found is los llanos de aridane with ID:  2514651
# ------------
# Retrieving Results for OpenWeather City Weather 523.
# City found is kathu with ID:  1153035
# ------------
# Retrieving Results for OpenWeather City Weather 524.
# City found is vikulovo with ID:  1487112
# ------------
# Retrieving Results for OpenWeather City Weather 525.
# City found is socorro with ID:  5530932
# ------------
# Retrieving Results for OpenWeather City Weather 526.
# City found is madingou with ID:  2257990
# ------------
# Retrieving Results for OpenWeather City Weather 527.
# City found is vila with ID:  7117100
# ------------
# Retrieving Results for OpenWeather City Weather 528.
# City found is wuda with ID:  1791325
# ------------
# Retrieving Results for OpenWeather City Weather 529.
# City found is boa vista with ID:  3664980
# ------------
# Retrieving Results for OpenWeather City Weather 530.
# City found is huangchuan with ID:  1807553
# ------------
# Retrieving Results for OpenWeather City Weather 531.
# City found is sortland with ID:  3137405
# ------------
# Retrieving Results for OpenWeather City Weather 532.
# City found is gornopravdinsk with ID:  1506268
# ------------
# Retrieving Results for OpenWeather City Weather 533.
# City found is yulara with ID:  6355222
# ------------
# Retrieving Results for OpenWeather City Weather 534.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 535.
# City found is gouyave with ID:  3580279
# ------------
# Retrieving Results for OpenWeather City Weather 536.
# City found is aykhal with ID:  2027296
# ------------
# Retrieving Results for OpenWeather City Weather 537.
# City found is hope with ID:  4115181
# ------------
# Retrieving Results for OpenWeather City Weather 538.
# City found is katherine with ID:  2068655
# ------------
# Retrieving Results for OpenWeather City Weather 539.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 540.
# City found is bambanglipuro with ID:  1650434
# ------------
# Retrieving Results for OpenWeather City Weather 541.
# City found is ilo with ID:  3938415
# ------------
# Retrieving Results for OpenWeather City Weather 542.
# City found is bitung with ID:  1648636
# ------------
# Retrieving Results for OpenWeather City Weather 543.
# City found is touros with ID:  3386213
# ------------
# Retrieving Results for OpenWeather City Weather 544.
# City found is barcelona with ID:  3128760
# ------------
# Retrieving Results for OpenWeather City Weather 545.
# City found is baykit with ID:  1510689
# ------------
# Retrieving Results for OpenWeather City Weather 546.
# City found is tshikapa with ID:  204953
# ------------
# Retrieving Results for OpenWeather City Weather 547.
# City found is kyotera with ID:  230256
# ------------
# Retrieving Results for OpenWeather City Weather 548.
# City found is cardston with ID:  5916821
# ------------
# Retrieving Results for OpenWeather City Weather 549.
# City found is ahipara with ID:  2194098
# ------------
# Retrieving Results for OpenWeather City Weather 550.
# City found is seoul with ID:  1835848
# ------------
# Retrieving Results for OpenWeather City Weather 551.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 552.
# City found is china with ID:  3530839
# ------------
# Retrieving Results for OpenWeather City Weather 553.
# City found is fortuna with ID:  5563839
# ------------
# Retrieving Results for OpenWeather City Weather 554.
# City found is kempele with ID:  653252
# ------------
# Retrieving Results for OpenWeather City Weather 555.
# City found is liku with ID:  1633034
# ------------
# Retrieving Results for OpenWeather City Weather 556.
# City found is paamiut with ID:  3421193
# ------------
# Retrieving Results for OpenWeather City Weather 557.
# City found is pingzhuang with ID:  2035453
# ------------
# Retrieving Results for OpenWeather City Weather 558.
# City found is aripuana with ID:  3665202
# ------------
# Retrieving Results for OpenWeather City Weather 559.
# City found is port-gentil with ID:  2396518
# ------------
# Retrieving Results for OpenWeather City Weather 560.
# City found is talnakh with ID:  1490256
# ------------
# Retrieving Results for OpenWeather City Weather 561.
# City found is carauari with ID:  3664659
# ------------
# Retrieving Results for OpenWeather City Weather 562.
# City found is sulangan with ID:  1685422
# ------------
# Retrieving Results for OpenWeather City Weather 563.
# City found is half moon bay with ID:  5354943
# ------------
# Retrieving Results for OpenWeather City Weather 564.
# City found is kurayoshi with ID:  1858301
# ------------
# Retrieving Results for OpenWeather City Weather 565.
# City found is nuuk with ID:  3421319
# ------------
# Retrieving Results for OpenWeather City Weather 566.
# City found is beaufort with ID:  1733874
# ------------
# Retrieving Results for OpenWeather City Weather 567.
# City found is ajaccio with ID:  3038333
# ------------
# Retrieving Results for OpenWeather City Weather 568.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 569.
# City found is bazarnyy karabulak with ID:  578466
# ------------
# Retrieving Results for OpenWeather City Weather 570.
# City found is lahan with ID:  1283161
# ------------
# Retrieving Results for OpenWeather City Weather 571.
# City found is senneterre with ID:  6144195
# ------------
# Retrieving Results for OpenWeather City Weather 572.
# City found is am timan with ID:  245338
# ------------
# Retrieving Results for OpenWeather City Weather 573.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 574.
# City found is pavlovskaya with ID:  512051
# ------------
# Retrieving Results for OpenWeather City Weather 575.
# City found is torres with ID:  3446295
# ------------
# Retrieving Results for OpenWeather City Weather 576.
# City found is biskamzha with ID:  1510030
# ------------
# Retrieving Results for OpenWeather City Weather 577.
# City found is kimbe with ID:  2093967
# ------------
# Retrieving Results for OpenWeather City Weather 578.
# City found is tonstad with ID:  3134327
# ------------
# Retrieving Results for OpenWeather City Weather 579.
# City found is east london with ID:  1006984
# ------------
# Retrieving Results for OpenWeather City Weather 580.
# City found is ambilobe with ID:  1082243
# ------------
# Retrieving Results for OpenWeather City Weather 581.
# City found is tygda with ID:  2014743
# ------------
# Retrieving Results for OpenWeather City Weather 582.
# City found is sinnai with ID:  6539309
# ------------
# Retrieving Results for OpenWeather City Weather 583.
# City found is torquay with ID:  2635650
# ------------
# Retrieving Results for OpenWeather City Weather 584.
# City found is zhuhai with ID:  1790437
# ------------
# Retrieving Results for OpenWeather City Weather 585.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 586.
# City found is doha with ID:  290030
# ------------
# Retrieving Results for OpenWeather City Weather 587.
# City found is andenes with ID:  3163146
# ------------
# Retrieving Results for OpenWeather City Weather 588.
# City found is masuguru with ID:  878054
# ------------
# Retrieving Results for OpenWeather City Weather 589.
# City found is beloha with ID:  1067565
# ------------
# Retrieving Results for OpenWeather City Weather 590.
# City found is cape coast with ID:  2302357
# ------------
# Retrieving Results for OpenWeather City Weather 591.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 592.
# City found is chanderi with ID:  1274755
# ------------
# Retrieving Results for OpenWeather City Weather 593.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 594.
# City found is punta cardon with ID:  3629614
# ------------
# Retrieving Results for OpenWeather City Weather 595.
# City found is jupiter with ID:  4160610
# ------------
# Retrieving Results for OpenWeather City Weather 596.
# City found is calarasi with ID:  618454
# ------------
# Retrieving Results for OpenWeather City Weather 597.
# City found is owensboro with ID:  4303436
# ------------
# Retrieving Results for OpenWeather City Weather 598.
# City found is zyryanka with ID:  2119283
# ------------
# Retrieving Results for OpenWeather City Weather 599.
# City found is wetaskiwin with ID:  6179602
# ------------
# Retrieving Results for OpenWeather City Weather 600.
# City found is bilibino with ID:  2126682
# ------------
# Retrieving Results for OpenWeather City Weather 601.
# City found is lata with ID:  2738381
# ------------
# Retrieving Results for OpenWeather City Weather 602.
# City found is buchanan with ID:  2278158
# ------------
# Retrieving Results for OpenWeather City Weather 603.
# City found is porto walter with ID:  3662761
# ------------
# Retrieving Results for OpenWeather City Weather 604.
# City found is salta with ID:  3838233
# ------------
# Retrieving Results for OpenWeather City Weather 605.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 606.
# City found is molteno with ID:  974719
# ------------
# Retrieving Results for OpenWeather City Weather 607.
# City found is mattru with ID:  2409215
# ------------
# Retrieving Results for OpenWeather City Weather 608.
# City found is srednekolymsk with ID:  2121025
# ------------
# Retrieving Results for OpenWeather City Weather 609.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 610.
# City found is ulaangom with ID:  1515029
# ------------
# Retrieving Results for OpenWeather City Weather 611.
# City found is richards bay with ID:  962367
# ------------
# Retrieving Results for OpenWeather City Weather 612.
# City found is cangucu with ID:  3467512
# ------------
# Retrieving Results for OpenWeather City Weather 613.
# City found is wick with ID:  2633982
# ------------
# Retrieving Results for OpenWeather City Weather 614.
# City found is kotka with ID:  650946
# ------------
# Retrieving Results for OpenWeather City Weather 615.
# City weather not available
# ------------
# Retrieving Results for OpenWeather City Weather 616.
# City found is camacha with ID:  2270385
# ------------
# Retrieving Results for OpenWeather City Weather 617.
# City found is xiongzhou with ID:  1788402
# ------------
# Retrieving Results for OpenWeather City Weather 618.
# City found is quelimane with ID:  1028434
# ------------
# Retrieving Results for OpenWeather City Weather 619.
# City found is constitucion with ID:  3893726
# ------------
# Retrieving Results for OpenWeather City Weather 620.
# City found is xunchang with ID:  1787901
# ------------
# Retrieving Results for OpenWeather City Weather 621.
# City found is krasnoselkup with ID:  1502073
# ------------
# Retrieving Results for OpenWeather City Weather 622.
# City found is aquiraz with ID:  3407407
# ------------
# Retrieving Results for OpenWeather City Weather 623.
# City found is odweyne with ID:  53372
# ------------
# Retrieving Results for OpenWeather City Weather 624.
# City found is cascais with ID:  2269594
# ------------
# Retrieving Results for OpenWeather City Weather 625.
# City found is banda aceh with ID:  1215502
# ------------
# Retrieving Results for OpenWeather City Weather 626.
# City found is bejar with ID:  3128382
# ------------
# Retrieving Results for OpenWeather City Weather 627.
# City found is laguna with ID:  5364271
# ------------
# Retrieving Results for OpenWeather City Weather 628.
# City found is oktyabrskiy with ID:  515879
# ------------
# Retrieving Results for OpenWeather City Weather 629.
# City found is baniachang with ID:  1185274
# ------------

# %%
#Get and Convert Date for Display
today_date = response['dt']
today_date = datetime.fromtimestamp(today_date)
today_date = pd.to_datetime(today_date) 
today_date
# Out:
# Timestamp('2022-02-04 12:46:03')

# %%
new_cities_df
# Out:
#               city country latitude longitude humidity cloudiness windspeed  \
# 0       lavrentiya      RU  65.5833      -171       55          0     18.07
# 1       maningrida      AU -12.0667  134.2667       86        100      6.29
# 2          rikitea      PF -23.1203 -134.9692       71         85      9.44
# 3        massakory      TD   12.996   15.7293       11          0      12.8
# 4    cockburn town      TC  21.4612  -71.1419       66          0     18.95
# ..             ...     ...      ...       ...      ...        ...       ...
# 625     banda aceh      ID   5.5577   95.3222       81         51      7.36
# 626          bejar      ES  40.3864   -5.7634       72        100      4.97
# 627         laguna      US   38.421 -121.4238       71          0      1.01
# 628    oktyabrskiy      RU  54.4815    53.471       87        100     10.09
# 629     baniachang      BD  24.5167   91.3667       85        100      4.99
#
#     temperature
# 0         -0.29
# 1         76.75
# 2         78.28
# 3         74.95
# 4         75.72
# ..          ...
# 625       78.33
# 626        49.5
# 627       50.43
# 628       27.91
# 629       61.38
#
# [630 rows x 8 columns]

# %%
#Removing cities that were not found with 404 Error or have values on NA
nan_value = float("NaN")
new_cities_df.replace("", nan_value, inplace=True)

new_cities_df.dropna(subset = ["latitude"], inplace=True)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export the City Data to a CSV
new_cities_df.to_csv('city_data.csv')

#Display the Data Frame
new_cities_df
# Out:
#               city country  latitude  longitude  humidity  cloudiness  \
# 0       lavrentiya      RU   65.5833  -171.0000      55.0         0.0
# 1       maningrida      AU  -12.0667   134.2667      86.0       100.0
# 2          rikitea      PF  -23.1203  -134.9692      71.0        85.0
# 3        massakory      TD   12.9960    15.7293      11.0         0.0
# 4    cockburn town      TC   21.4612   -71.1419      66.0         0.0
# ..             ...     ...       ...        ...       ...         ...
# 625     banda aceh      ID    5.5577    95.3222      81.0        51.0
# 626          bejar      ES   40.3864    -5.7634      72.0       100.0
# 627         laguna      US   38.4210  -121.4238      71.0         0.0
# 628    oktyabrskiy      RU   54.4815    53.4710      87.0       100.0
# 629     baniachang      BD   24.5167    91.3667      85.0       100.0
#
#      windspeed  temperature
# 0        18.07        -0.29
# 1         6.29        76.75
# 2         9.44        78.28
# 3        12.80        74.95
# 4        18.95        75.72
# ..         ...          ...
# 625       7.36        78.33
# 626       4.97        49.50
# 627       1.01        50.43
# 628      10.09        27.91
# 629       4.99        61.38
#
# [570 rows x 8 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#check if there are any cities with >100% humidity
humidity_check = new_cities_df["humidity"].describe(include = "all")
print("The maximum humidity value is 100, so there is no humidity value over 100 in our data set")
humidity_check
# Out:
# The maximum humidity value is 100, so there is no humidity value over 100 in our data set
# count    570.000000
# mean      72.719298
# std       21.217805
# min        6.000000
# 25%       62.000000
# 50%       76.000000
# 75%       89.000000
# max      100.000000
# Name: humidity, dtype: float64

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Using ggplot
plt.style.use('ggplot')

# Manage the size of the plot
fig_size = plt.rcParams["figure.figsize"] # current plot size
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size # manage plot size


# Print scatter plot
plt.scatter(new_cities_df["latitude"], new_cities_df["temperature"])
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.xlim(-90,90)
plt.title(f"Termperature by Latitude for {len(new_cities_df)} Cities. \n" + "As of: " + str(today_date))

         
plt.savefig("Temp_VS_Lat.png")

# %%
# This plot is showing the temperatures in random cities selected across the globe in late January based
# on the cities latitude.  The analysis # (as expected) that the temperatures gradually decrease in both the
# Northern and Southern hemisphere as you move away from the equator between 40 degrees latitude, and then
# decrease significantly in the Northen Hemisphere where they are experiencing winter.  
# Would expect to see a similar tail to the left if this was run in July in the Southern Hemisphere.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Using ggplot
plt.style.use('ggplot')

# Manage the size of the plot
fig_size = plt.rcParams["figure.figsize"] # current plot size
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size # manage plot size

# Print scatter plot
plt.scatter(new_cities_df["latitude"], new_cities_df["humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim(-90,90)
plt.title(f"Humidity by Latitude for {len(new_cities_df)} Cities. \n" + "As of: " + str(today_date))

         
plt.savefig("Humidity_VS_Lat.png")

# %%
# This chart is showing percent humidity by latitude for random cities selected across the globe.  It's  interesting 
# in that that most of the humidity values are in the 60 to 100% range with a cluster of values near 100% in the 
# Norther latutudes in the winter. This makes sense because the potential amount of water air can hold is lower at 
# lower temperatures so the denominator in the relative humidity equation is decreasing as the latitude increases.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Using ggplot
plt.style.use('ggplot')

# Manage the size of the plot
fig_size = plt.rcParams["figure.figsize"] # current plot size
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size # manage plot size

# Print scatter plot

plt.scatter(new_cities_df["latitude"], new_cities_df["cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Clouds (%)")
plt.xlim(-90,90)
plt.title(f"Cloudiness by Latitude for {len(new_cities_df)} Cities. \n" + "As of: " + str(today_date))

         
plt.savefig("Cloud_VS_Lat.png")

# %%
# The chart is measuring the percentage of clouds in the sky across randomly selected cities of different latitude. 
# One thing to note is that the results cluster on the upper and lower bounds which makes sense in that in many 
# cities on any given day given the weather there can be no clouds or complete cloud cover.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Using ggplot 
plt.style.use('ggplot')

# Manage the size of the plot
fig_size = plt.rcParams["figure.figsize"] # current plot size
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size # manage plot size

# Print scatter plot
plt.scatter(new_cities_df["latitude"], new_cities_df["windspeed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlim(-90,90)
plt.title(f"Wind Speed by Latitude for {len(new_cities_df)} Cities. \n" + "As of: " + str(today_date))

         
plt.savefig("Wind_VS_Lat.png")

# %%
# This chart is measureing wind speed for randomly selected cities across the globe.  It's showing that wind speeds
# tend to be between 0 and 10 mph across the globe and the season, summer or winter doesn't appear to have much of an
# impact on winds.

# %% [markdown]
# ## Linear Regression

# %%
# Generate North/South Hemi DF

# Southern cities

south_cities = new_cities_df.loc[new_cities_df["latitude"] <= 0]
south_cities_ct = len(south_cities)


# Northern cities

north_cities = new_cities_df.loc[new_cities_df["latitude"] > 0]
north_cities_ct = len(north_cities)

#north_cities
north_cities
#print("There are {} cities in the northern hemisphere out of {} cities total, representing {:.1%} of all cities in the data set."
#     .format(northern_cities_count, city_left_count, (northern_cities_count/city_left_count)))
# Out:
#               city country  latitude  longitude  humidity  cloudiness  \
# 0       lavrentiya      RU   65.5833  -171.0000      55.0         0.0
# 3        massakory      TD   12.9960    15.7293      11.0         0.0
# 4    cockburn town      TC   21.4612   -71.1419      66.0         0.0
# 5           albany      US   42.6001   -73.9662      87.0       100.0
# 6       tyukalinsk      RU   55.8732    72.1967      80.0       100.0
# ..             ...     ...       ...        ...       ...         ...
# 625     banda aceh      ID    5.5577    95.3222      81.0        51.0
# 626          bejar      ES   40.3864    -5.7634      72.0       100.0
# 627         laguna      US   38.4210  -121.4238      71.0         0.0
# 628    oktyabrskiy      RU   54.4815    53.4710      87.0       100.0
# 629     baniachang      BD   24.5167    91.3667      85.0       100.0
#
#      windspeed  temperature
# 0        18.07        -0.29
# 3        12.80        74.95
# 4        18.95        75.72
# 5         1.99        16.25
# 6        13.00        21.24
# ..         ...          ...
# 625       7.36        78.33
# 626       4.97        49.50
# 627       1.01        50.43
# 628      10.09        27.91
# 629       4.99        61.38
#
# [383 rows x 8 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform Regression and Plot Results

x_values = north_cities["latitude"] 
y_values = north_cities["temperature"]  
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f" The R-value is " , rvalue)

# Print the Regression formula
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title(f"Northern Hemisphere Termperature by Latitude \n" + "As of: " + str(today_date))

plt.savefig("North_Temp_VS_Lat_Reg.png")
# Out:
#  The R-value is  -0.8722154312672009

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform Regression and Plot Results

x_values = south_cities["latitude"] 
y_values = south_cities["temperature"]  
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f" The R-value is " , rvalue)

# Print the Regression formula
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title(f" Southern Hemisphere - Termperature by Latitude \n" + "As of: " + str(today_date))
plt.xlim([5, -60])
plt.ylim([-40,100])

plt.savefig("South_Temp_VS_Lat_Reg.png")
# Out:
#  The R-value is  0.5577925649991926

# %%
# The first thing I noticed is that the overall correlation between temperature and latitude is stonger in the
# Northern Hemispheres.  I plotted the output on the same scale so I could better see
# any differences in the regression, as before doing so, the regression looked stonger in the Norther Hemisphere. 
# Showing the results on the same Y axix scale shows that both Norther and Southern Hemisphere correlations appear 
# equally strong despite the difference in R values.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform Regression and Plot Results

x_values = north_cities["latitude"] 
y_values = north_cities["humidity"]  
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f" The R-value is " , rvalue)
 

# Print the Regression formula
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Northern Hemisphere - Humidity by Latitude\n" + "As of: " + str(today_date))

plt.savefig("North_Humidity_VS_Lat_Reg.png")
# Out:
#  The R-value is  0.4116394191312621

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform Regression and Plot Results

x_values = south_cities["latitude"] 
y_values = south_cities["humidity"]  
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f" The R-value is " , rvalue)
 
# Print the Regression formula
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Southern Hemisphere - Humidity by Latitude \n" + "As of: " + str(today_date))

plt.savefig("South_Humidity_VS_Lat_Reg.png")
# Out:
#  The R-value is  0.2777004558817605

# %%
# With and R-Value of .41 and .27 for the Northern and Southern Hemispheres respectively, there appears to be 
# correlation between latitude and humidity in the North but little in the South.  The higher .41 R value in the North
# as discussed above, could be explained by the fact that, given it's wintner and the cold weather season.  
# Given the potential amount of water air can hold is lower at lower temperatures, in the winter the denominator in the 
# relative humidity equation is decreasing as the latitude increases which causes the Relative Humidity numbers 
# to move toward 100% at low temperatures.  My assumption is that, if we ran this same regression in July, the Southern 
# Hemisphere's winter, we'd see the reverse of what we are seeing here, or the South correlation higher than the North.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Perform Regression and Plot Results

x_values = north_cities["latitude"] 
y_values = north_cities["cloudiness"]  
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f" The R-value is " , rvalue)

# Print the Regression formula
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(60,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"Norther Hemisphere - Cloudiness by Latitude \n" + "As of: " + str(today_date))

plt.savefig("North_Cloud_VS_Lat_Reg.png")
# Out:
#  The R-value is  0.33624932459572954

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Perform Regression and Plot Results

x_values = south_cities["latitude"] 
y_values = south_cities["cloudiness"]  
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f" The R-value is " , rvalue)
      
# Print the Regression formula()
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-53,81),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"Souther Hemisphere - Cloudiness by Latitude \n" + "As of: " + str(today_date))

plt.savefig("South_Clouds_VS_Lat_Reg.png")
# Out:
#  The R-value is  0.2876828768414238

# %%
#  There appears to be, and the R-Values of 33 and 24 confirm that there is little or no correlation between cloudiness 
#  and latitude in either hemisphere.
#  As discussed above, there is some clustering of resulting on the boundaries given the tendencies for very high p
#  pressure days to have no clouds and very low pressure days to be 100% cloudy.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Perform Regression and Plot Results

x_values = north_cities["latitude"] 
y_values = north_cities["windspeed"]  
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Print the Regression formula
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Northern Hemisphere - Wind Speed by Latitude \n" + "As of: " + str(today_date))

plt.savefig("North_Wind_VS_Lat_Reg.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Perform Regression and Plot Results

x_values = south_cities["latitude"] 
y_values = south_cities["windspeed"]  
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Print the Regression formula
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,26),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed  (mph)")
plt.title(f" Sourhtern Hemisphere - Wind Speed by Latitude\n" + "As of: " + str(today_date))

plt.savefig("South_Wind_VS_Lat_Reg.png")

# %%
# There appears to be very litte correlation between Wind Speed and Latitude in either hemisphere.  Winds do tend to 
# range between 0 and 10 miles per hour in both hemispheres.
